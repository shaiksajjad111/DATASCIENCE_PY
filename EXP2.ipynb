# %% [markdown]
# **EXPERIMENT 2**

# %%
import pandas as pd
data=pd.read_excel("content.xlsx",index_col=0)
print(data)
print("first 6 rows")
print(data.head(6))
data.head(6).to_excel("test.xlsx",index=True)
# Out:
#         Name  Roll No   CGPA Address
# Sno
# 1      kamal      1289   9.0     MTM
# 2     sajjad      1273   8.0     vja
# 3    praveen      1280   7.0     MTM
# 4    sumanth      1290   8.8     MTM
# 5    yugendh      1231   9.0     MTM
# 6       sita      1267   6.0     MTM
# 7      githa      1245   4.0     MTM
# 8       roja      1223   9.0     MTM
# 9       rani      1234   9.0     MTM
# 10    harsha      1289   9.0     MTM
# first 6 rows
#         Name  Roll No   CGPA Address
# Sno
# 1      kamal      1289   9.0     MTM
# 2     sajjad      1273   8.0     vja
# 3    praveen      1280   7.0     MTM
# 4    sumanth      1290   8.8     MTM
# 5    yugendh      1231   9.0     MTM
# 6       sita      1267   6.0     MTM
